# %% [markdown]
# <a href="https://colab.research.google.com/github/Rummenigge174/Math/blob/master/Lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=5
y=3
print(x+y)
# Out:
# 8

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 1000)
plt.plot(x, np.sin(2*x))
plt.plot(x, np.sin(x))
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.grid(True)
plt.show()
